os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

# %%
target = []
images = []
flat_data = []

# %% [markdown]
# #### Data prepocessing

# %%
datadir = 'C:/Users/khatr/Downloads/jupitor_notebook/project/Image_classification/Images'
catagories = ['daisy flower', 'lavender flower', 'rose flower', 'sunflower', 'tulip flower']
for catagory in catagories:
    class_num = catagories.index(catagory) # label encoding the values 
    path = os.path.join(datadir,catagory)
    for img in os.listdir(path):
        try:
            img_array = imread(os.path.join(path,img))
        # print(img_array)
        # print(img_array.shape)
        
            img_resized = resize(img_array, (150,150,3)) # normalizes the values from 0 to 1
            flat_data.append(img_resized.flatten())
            images.append(img_resized) 
            target.append(class_num)
        except (IOError,ValueError) as e:
            print('could not read the:',e,'hence skipping it.')
# flat_data = np.array(flat_data)
# target = np.array(target)
# images = np.array(images)
# Out:
# could not read the: Could not find a format to read the specified file in single-image mode hence skipping it.

# %%
flat_data = np.array(flat_data)
target = np.array(target)
images = np.array(images)

# %%
flat_data.shape
# Out:
# (174, 67500)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(flat_data, target)

# %%
len(X_train)
# Out:
# 130

# %% [markdown]
# ## SVM model

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import svm

paran_grid = [{'C':[1,10,100,1000], 'kernel': ['linear']},
              {'C':[1,10,100,1000], 'kernel': ['rbf'], 'gamma':[0.001, 0.0001]}
             ]

svc = svm.SVC(probability = True)
clf = GridSearchCV(svc,paran_grid )
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(probability=True),
#              param_grid=[{'C': [1, 10, 100, 1000], 'kernel': ['linear']},
#                          {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001],
#                           'kernel': ['rbf']}])

# %%
y_pred  = clf.predict(X_test)
y_pred
# Out:
# array([0, 4, 4, 3, 1, 3, 0, 0, 0, 3, 2, 3, 0, 4, 0, 3, 1, 0, 0, 2, 2, 0,
#        0, 4, 1, 1, 2, 3, 1, 0, 0, 0, 2, 0, 1, 2, 2, 0, 0, 2, 0, 3, 0, 0])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy = accuracy_score(y_pred, y_test)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 36.36%

# %%
#confusion matrix for SVM
confusion_matrix(y_pred, y_test)
# Out:
# array([[6, 2, 2, 4, 5],
#        [1, 1, 1, 1, 2],
#        [0, 2, 3, 3, 0],
#        [0, 1, 1, 5, 0],
#        [0, 0, 2, 1, 1]], dtype=int64)

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### XGB Model

# %%
from xgboost import XGBClassifier

XGB = XGBClassifier()
param_grid_XGB = [{'booster':['gbtree','gblinear'], 'max_depth': ['5', '9']}]
clf_XGB = GridSearchCV(XGB,param_grid_XGB )
clf_XGB.fit(X_train, y_train)
# Out:
# C:\Users\khatr\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:29:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
# make predictions for test data
y_pred_XGB = clf_XGB.predict(X_test)
accuracy = accuracy_score(y_pred_XGB, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 56.82%

# %%
#XGB confusion matrix

confusion_matrix(y_pred_XGB, y_test)
# Out:
# array([[5, 0, 2, 3, 3],
#        [1, 2, 1, 1, 0],
#        [0, 4, 2, 4, 2],
#        [1, 0, 3, 4, 1],
#        [0, 0, 1, 2, 2]], dtype=int64)

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
param_grid_DT = [{'splitter':['best','random'], 'criterion':['gini', 'entropy']}]
clf_DT = GridSearchCV(DT, param_grid_DT)
clf_DT.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid=[{'criterion': ['gini', 'entropy'],
#                           'splitter': ['best', 'random']}])

# %%
# make predictions for test data
y_pred_DT = clf_DT.predict(X_test)
accuracy = accuracy_score(y_pred_DT, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 36.36%

# %%
clf_DT.best_params_
# Out:
# {'criterion': 'gini', 'splitter': 'best'}

# %%
# Decision Tree confusion matrix

confusion_matrix(y_pred_DT, y_test)
# Out:
# array([[4, 0, 2, 4, 1],
#        [1, 3, 3, 2, 1],
#        [0, 2, 0, 1, 2],
#        [1, 1, 1, 4, 1],
#        [1, 0, 3, 3, 3]], dtype=int64)

# %% [markdown]
# ### Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
param_grid_LR = [{'solver':['liblinear', 'saga', 'newton-cg'], 'penalty' : ['l1', 'l2', 'elasticnet', 'none']}]
clf_LR = GridSearchCV(LR, param_grid_LR)
clf_LR.fit(X_train, y_train)
# Out:
# C:\Users\khatr\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\khatr\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\khatr\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\khatr\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# ...

# %%
# make predictions for test data
y_pred_LR = clf_LR.predict(X_test)
accuracy = accuracy_score(y_pred_LR, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 63.64%

# %%
# Decision Tree confusion matrix

confusion_matrix(y_pred_LR, y_test)
# Out:
# array([[2, 2, 5, 2, 3],
#        [2, 1, 1, 1, 1],
#        [2, 1, 3, 2, 2],
#        [1, 2, 0, 8, 0],
#        [0, 0, 0, 1, 2]], dtype=int64)

# %%
clf_LR.best_params_
# Out:
# {'penalty': 'l1', 'solver': 'saga'}

# %% [markdown]
# ### K-Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN = KNeighborsClassifier()
param_grid_KNN = [{'n_neighbors': [2,5],'p' : [2,3], 'weights' : ['uniform', 'distance'], 'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute']}]
clf_KNN = GridSearchCV(KNN, param_grid_KNN)
clf_KNN.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid=[{'algorithm': ['auto', 'ball_tree', 'kd_tree',
#                                         'brute'],
#                           'n_neighbors': [2, 5], 'p': [2, 3],
#                           'weights': ['uniform', 'distance']}])

# %%
# make predictions for test data
y_pred_KNN = clf_KNN.predict(X_test)
accuracy = accuracy_score(y_pred_KNN, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 34.09%

# %%
clf_KNN.best_score_
# Out:
# 0.3384615384615385

# %%
clf_KNN.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 2, 'p': 2, 'weights': 'distance'}

# %%
confusion_matrix(y_pred_KNN, y_test)
# Out:
# array([[2, 0, 0, 1, 2],
#        [3, 1, 1, 3, 1],
#        [1, 2, 6, 3, 2],
#        [1, 2, 2, 3, 2],
#        [0, 1, 0, 4, 1]], dtype=int64)

# %% [markdown]
# ##### Models ACcuracy using Cross Validation techniqe

# %%
from sklearn.model_selection import ShuffleSplit, cross_val_score

ss = ShuffleSplit(n_splits=5, test_size=0.3, random_state=5)

# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

def bestmodel(x,y):

    algos = {
        'logistic_regression' : {
            'model': LogisticRegression(),
            'params': {
                'solver': ['liblinear', 'saga', 'newton-cg'],
                'penalty' : ['l1', 'l2', 'elasticnet', 'none']
            }
        },
        
            'KNeighbors' : {
                'model': KNeighborsClassifier(),
                'params':{
                    'n_neighbors': [2,5],
                    'p' : [2,3],
                    
                }
            
        },
        
        'XGB': {
            'model': XGBClassifier(),
            'params': {
                'booster': ['gbtree','gblinear'],
                'max_depth': ['5', '9']
                }
            
        },
        'decision_tree': {
            'model': DecisionTreeClassifier(),
            'params': {
                
                'splitter': ['best','random'],
                'criterion':['gini', 'entropy']
            }
        }
    }
    scores = []
    for name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=ss, return_train_score=False)
        gs.fit(x,y)
        scores.append({
            'model': name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

# %%
bestmodel(flat_data,target)
# Out:
# C:\Users\khatr\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\khatr\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\khatr\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\khatr\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# ...

# %% [markdown]
# ### CNN Model

# %%
import tensorflow
from tensorflow.keras import layers
from tensorflow.keras import models
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150,150,3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.summary()
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(5, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_5 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 34, 34, 64)        36928
#
# ...
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_5 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 72, 72, 64)        18496
#
# ...

# %%
X_train = X_train.reshape((130, 150, 150, 3))
X_train = X_train.astype('float32')
X_test = X_test.reshape((44, 150, 150, 3))
X_test = X_test.astype('float32')

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100)
test_loss, test_acc = model.evaluate(X_test, y_test)
test_acc
# Out:
# Epoch 1/100
# 5/5 [==============================] - 3s 429ms/step - loss: 3.7303 - accuracy: 0.2077
# Epoch 2/100
# 5/5 [==============================] - 2s 344ms/step - loss: 1.6074 - accuracy: 0.2923
# Epoch 3/100
# 5/5 [==============================] - 2s 323ms/step - loss: 1.6105 - accuracy: 0.3077
# Epoch 4/100
# 5/5 [==============================] - 2s 314ms/step - loss: 1.5348 - accuracy: 0.3231
# Epoch 5/100
# 5/5 [==============================] - 2s 311ms/step - loss: 1.4655 - accuracy: 0.3462
# Epoch 6/100
# 5/5 [==============================] - 2s 312ms/step - loss: 1.4940 - accuracy: 0.3923
# Epoch 7/100
# 5/5 [==============================] - 2s 315ms/step - loss: 1.4196 - accuracy: 0.4308
# Epoch 8/100
# 5/5 [==============================] - 2s 318ms/step - loss: 1.3070 - accuracy: 0.5154
# Epoch 9/100
# 5/5 [==============================] - 2s 313ms/step - loss: 1.1765 - accuracy: 0.5308
# Epoch 10/100
# ...

# %% [markdown]
# ### CNN with Data Augmentation

# %%
data_augmentation = tensorflow.keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(150, 
                                                              150,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),

  ]
)

# %%
model2 = models.Sequential([
  data_augmentation,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(5, activation='softmax')
])
model2.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential_4 (Sequential)   (None, 150, 150, 3)       0
#
#  conv2d_9 (Conv2D)           (None, 150, 150, 16)      448
#
#  max_pooling2d_7 (MaxPooling  (None, 75, 75, 16)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 75, 75, 32)        4640
#
#  max_pooling2d_8 (MaxPooling  (None, 37, 37, 32)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 37, 37, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 18, 18, 64)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 20736)             0
#
#  dense_6 (Dense)             (None, 128)               2654336
#
#  dense_7 (Dense)             (None, 5)                 645
#
# ...
# Total params: 2,678,565
# Trainable params: 2,678,565
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model2.fit(X_train, y_train, epochs=100)
test_loss, test_acc = model2.evaluate(X_test, y_test)
test_acc
# Out:
# Epoch 1/100
# 5/5 [==============================] - 2s 201ms/step - loss: 2.3544 - accuracy: 0.1769
# Epoch 2/100
# 5/5 [==============================] - 1s 197ms/step - loss: 1.6173 - accuracy: 0.2462
# Epoch 3/100
# 5/5 [==============================] - 1s 202ms/step - loss: 1.5897 - accuracy: 0.2462
# Epoch 4/100
# 5/5 [==============================] - 1s 201ms/step - loss: 1.5932 - accuracy: 0.2231
# Epoch 5/100
# 5/5 [==============================] - 1s 201ms/step - loss: 1.5805 - accuracy: 0.2692
# Epoch 6/100
# 5/5 [==============================] - 1s 199ms/step - loss: 1.5647 - accuracy: 0.2462
# Epoch 7/100
# 5/5 [==============================] - 1s 199ms/step - loss: 1.5458 - accuracy: 0.2923
# Epoch 8/100
# 5/5 [==============================] - 1s 201ms/step - loss: 1.5035 - accuracy: 0.3769
# Epoch 9/100
# 5/5 [==============================] - 1s 199ms/step - loss: 1.4854 - accuracy: 0.3154
# Epoch 10/100
# ...

# %%
pred_cnn = model2.predict(X_test)

# %%
pred_CNN = [np.argmax(element) for element in pred_cnn]

# %%
y_test_arg=np.argmax(y_test,axis=1)
accuracy_score(y_test_arg, np.argmax(pred_cnn, axis=1))
# Out:
# 0.5

# %%
print(confusion_matrix(y_test_arg, pred_CNN))
# Out:
# [[4 1 0 1 1]
#  [1 2 1 2 0]
#  [1 1 4 0 3]
#  [1 1 0 9 3]
#  [3 1 0 1 3]]
